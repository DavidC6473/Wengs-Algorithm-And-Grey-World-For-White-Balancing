# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow, imsave

# %%
a_reference_image = imread("Truth/true-0063.png") 
a_test_image1 = imread("Test/test-0063_F_AS.png")
a_test_image2 = imread("Test/test-0063_F_CS.png")
a_test_image3 = imread("Test/test-0063_F_FF.png")
a_test_image4 = imread("Test/test-0063_F_L.png")
a_test_image5 = imread("Test/test-0063_F_N.png")
a_test_image6 = imread("Test/test-0063_F_P.png")
a_test_image7 = imread("Test/test-0063_S_AS.png")
a_test_image8 = imread("Test/test-0063_S_CS.png")
a_test_image9 = imread("Test/test-0063_S_FF.png")
a_test_image10 = imread("Test/test-0063_S_L.png")
a_test_image11 = imread("Test/test-0063_S_N.png")
a_test_image12 = imread("Test/test-0063_S_P.png")
b_reference_image = imread("Truth/true-0070.png") 
b_test_image1 = imread("Test/test-0070_F_AS.png")
b_test_image2 = imread("Test/test-0070_F_CS.png")
b_test_image3 = imread("Test/test-0070_F_FF.png")
b_test_image4 = imread("Test/test-0070_F_L.png")
b_test_image5 = imread("Test/test-0070_F_N.png")
b_test_image6 = imread("Test/test-0070_F_P.png")
b_test_image7 = imread("Test/test-0070_S_AS.png")
b_test_image8 = imread("Test/test-0070_S_CS.png")
b_test_image9 = imread("Test/test-0070_S_FF.png")
b_test_image10 = imread("Test/test-0070_S_L.png")
b_test_image11 = imread("Test/test-0070_S_N.png")
b_test_image12 = imread("Test/test-0070_S_P.png")
c_reference_image = imread("Truth/true-0072.png") 
c_test_image1 = imread("Test/test-0072_F_AS.png")
c_test_image2 = imread("Test/test-0072_F_CS.png")
c_test_image3 = imread("Test/test-0072_F_FF.png")
c_test_image4 = imread("Test/test-0072_F_L.png")
c_test_image5 = imread("Test/test-0072_F_N.png")
c_test_image6 = imread("Test/test-0072_F_P.png")
c_test_image7 = imread("Test/test-0072_S_AS.png")
c_test_image8 = imread("Test/test-0072_S_CS.png")
c_test_image9 = imread("Test/test-0072_S_FF.png")
c_test_image10 = imread("Test/test-0072_S_L.png")
c_test_image11 = imread("Test/test-0072_S_N.png")
c_test_image12 = imread("Test/test-0072_S_P.png")
d_reference_image = imread("Truth/true-0097.png") 
d_test_image1 = imread("Test/test-0097_F_AS.png")
d_test_image2 = imread("Test/test-0097_F_CS.png")
d_test_image3 = imread("Test/test-0097_F_FF.png")
d_test_image4 = imread("Test/test-0097_F_L.png")
d_test_image5 = imread("Test/test-0097_F_N.png")
d_test_image6 = imread("Test/test-0097_F_P.png")
d_test_image7 = imread("Test/test-0097_S_AS.png")
d_test_image8 = imread("Test/test-0097_S_CS.png")
d_test_image9 = imread("Test/test-0097_S_FF.png")
d_test_image10 = imread("Test/test-0097_S_L.png")
d_test_image11 = imread("Test/test-0097_S_N.png")
d_test_image12 = imread("Test/test-0097_S_P.png")
e_reference_image = imread("Truth/true-0104.png") 
e_test_image1 = imread("Test/test-0104_F_AS.png")
e_test_image2 = imread("Test/test-0104_F_CS.png")
e_test_image3 = imread("Test/test-0104_F_FF.png")
e_test_image4 = imread("Test/test-0104_F_L.png")
e_test_image5 = imread("Test/test-0104_F_N.png")
e_test_image6 = imread("Test/test-0104_F_P.png")
e_test_image7 = imread("Test/test-0104_S_AS.png")
e_test_image8 = imread("Test/test-0104_S_CS.png")
e_test_image9 = imread("Test/test-0104_S_FF.png")
e_test_image10 = imread("Test/test-0104_S_L.png")
e_test_image11 = imread("Test/test-0104_S_N.png")
e_test_image12 = imread("Test/test-0104_S_P.png")

# %%
def gw(img):
    red_cpt = img[:,:,0]
    green_cpt = img[:,:,1]
    blue_cpt = img[:,:,2]
    
    np.mean(red_cpt)
    np.mean(green_cpt)
    np.mean(blue_cpt)
    
    red_gain = np.mean(green_cpt) / np.mean(red_cpt)
    blue_gain = np.mean(green_cpt) / np.mean(blue_cpt)
    
    adj_red_cpt = red_cpt * red_gain
    adj_blue_cpt = blue_cpt * blue_gain
    
    adj_red_cpt = np.clip(red_cpt * red_gain, 0, 255).astype('uint8')
    adj_blue_cpt = np.clip(blue_cpt * blue_gain, 0, 255).astype('uint8')
    adj_green_cpt = green_cpt # no type conversion required as we have not multiplied by a float
    
    # extract each component from the image
    r = img[:,:,0]
    g = img[:,:,1]
    b = img[:,:,2]
    
    # Grey World gain for red and blue components
    alpha = np.mean(g) / np.mean(r)
    beta = np.mean(g) / np.mean(b)
    
    # adjust by gain, clip to range [0, 255] 
    # convert to unsigned 8-bit integer (unit8) - whole number between 0 and 255
    a_r = np.clip(alpha * r, 0, 255).astype('uint8')
    a_g = g.astype('uint8')
    a_b = np.clip(beta * b, 0, 255).astype('uint8')
    
    # create a colour image by creating a numpy array
    # stacking the adjusted component arrays in depth order
    
    return np.dstack((a_r, a_g, a_b))

# %%
a_weng_reference_image = gw(a_reference_image)
a_weng_test_image1 = gw(a_test_image1)
a_weng_test_image2 = gw(a_test_image2)
a_weng_test_image3 = gw(a_test_image3)
a_weng_test_image4 = gw(a_test_image4)
a_weng_test_image5 = gw(a_test_image5)
a_weng_test_image6 = gw(a_test_image6)
a_weng_test_image7 = gw(a_test_image7)
a_weng_test_image8 = gw(a_test_image8)
a_weng_test_image9 = gw(a_test_image9)
a_weng_test_image10 = gw(a_test_image10)
a_weng_test_image11 = gw(a_test_image11)
a_weng_test_image12 = gw(a_test_image12)
b_weng_reference_image = gw(b_reference_image)
b_weng_test_image1 = gw(b_test_image1)
b_weng_test_image2 = gw(b_test_image2)
b_weng_test_image3 = gw(b_test_image3)
b_weng_test_image4 = gw(b_test_image4)
b_weng_test_image5 = gw(b_test_image5)
b_weng_test_image6 = gw(b_test_image6)
b_weng_test_image7 = gw(b_test_image7)
b_weng_test_image8 = gw(b_test_image8)
b_weng_test_image9 = gw(b_test_image9)
b_weng_test_image10 = gw(b_test_image10)
b_weng_test_image11 = gw(b_test_image11)
b_weng_test_image12 = gw(b_test_image12)
c_weng_reference_image = gw(c_reference_image)
c_weng_test_image1 = gw(c_test_image1)
c_weng_test_image2 = gw(c_test_image2)
c_weng_test_image3 = gw(c_test_image3)
c_weng_test_image4 = gw(c_test_image4)
c_weng_test_image5 = gw(c_test_image5)
c_weng_test_image6 = gw(c_test_image6)
c_weng_test_image7 = gw(c_test_image7)
c_weng_test_image8 = gw(c_test_image8)
c_weng_test_image9 = gw(c_test_image9)
c_weng_test_image10 = gw(c_test_image10)
c_weng_test_image11 = gw(c_test_image11)
c_weng_test_image12 = gw(c_test_image12)
d_weng_reference_image = gw(d_reference_image)
d_weng_test_image1 = gw(d_test_image1)
d_weng_test_image2 = gw(d_test_image2)
d_weng_test_image3 = gw(d_test_image3)
d_weng_test_image4 = gw(d_test_image4)
d_weng_test_image5 = gw(d_test_image5)
d_weng_test_image6 = gw(d_test_image6)
d_weng_test_image7 = gw(d_test_image7)
d_weng_test_image8 = gw(d_test_image8)
d_weng_test_image9 = gw(d_test_image9)
d_weng_test_image10 = gw(d_test_image10)
d_weng_test_image11 = gw(d_test_image11)
d_weng_test_image12 = gw(d_test_image12)
e_weng_reference_image = gw(e_reference_image)
e_weng_test_image1 = gw(e_test_image1)
e_weng_test_image2 = gw(e_test_image2)
e_weng_test_image3 = gw(e_test_image3)
e_weng_test_image4 = gw(e_test_image4)
e_weng_test_image5 = gw(e_test_image5)
e_weng_test_image6 = gw(e_test_image6)
e_weng_test_image7 = gw(e_test_image7)
e_weng_test_image8 = gw(e_test_image8)
e_weng_test_image9 = gw(e_test_image9)
e_weng_test_image10 = gw(e_test_image10)
e_weng_test_image11 = gw(e_test_image11)
e_weng_test_image12 = gw(e_test_image12)

# %%
imsave("Truth/true-0063_GW.png", a_weng_reference_image)
imsave("Test/test-0063_F_AS_GW.png", a_weng_test_image1)
imsave("Test/test-0063_F_CS_GW.png", a_weng_test_image2)
imsave("Test/test-0063_F_FF_GW.png", a_weng_test_image3)
imsave("Test/test-0063_F_L_GW.png", a_weng_test_image4)
imsave("Test/test-0063_F_N_GW.png", a_weng_test_image5)
imsave("Test/test-0063_F_P_GW.png", a_weng_test_image6)
imsave("Test/test-0063_S_AS_GW.png", a_weng_test_image7)
imsave("Test/test-0063_S_CS_GW.png", a_weng_test_image8)
imsave("Test/test-0063_S_FF_GW.png", a_weng_test_image9)
imsave("Test/test-0063_S_L_GW.png", a_weng_test_image10)
imsave("Test/test-0063_S_N_GW.png", a_weng_test_image11)
imsave("Test/test-0063_S_P_GW.png", a_weng_test_image12)
imsave("Truth/true-0070_GW.png", b_weng_reference_image)
imsave("Test/test-0070_F_AS_GW.png", b_weng_test_image1)
imsave("Test/test-0070_F_CS_GW.png", b_weng_test_image2)
imsave("Test/test-0070_F_FF_GW.png", b_weng_test_image3)
imsave("Test/test-0070_F_L_GW.png", b_weng_test_image4)
imsave("Test/test-0070_F_N_GW.png", b_weng_test_image5)
imsave("Test/test-0070_F_P_GW.png", b_weng_test_image6)
imsave("Test/test-0070_S_AS_GW.png", b_weng_test_image7)
imsave("Test/test-0070_S_CS_GW.png", b_weng_test_image8)
imsave("Test/test-0070_S_FF_GW.png", b_weng_test_image9)
imsave("Test/test-0070_S_L_GW.png", b_weng_test_image10)
imsave("Test/test-0070_S_N_GW.png", b_weng_test_image11)
imsave("Test/test-0070_S_P_GW.png", b_weng_test_image12)
imsave("Truth/true-0072_GW.png", c_weng_reference_image)
imsave("Test/test-0072_F_AS_GW.png", c_weng_test_image1)
imsave("Test/test-0072_F_CS_GW.png", c_weng_test_image2)
imsave("Test/test-0072_F_FF_GW.png", c_weng_test_image3)
imsave("Test/test-0072_F_L_GW.png", c_weng_test_image4)
imsave("Test/test-0072_F_N_GW.png", c_weng_test_image5)
imsave("Test/test-0072_F_P_GW.png", c_weng_test_image6)
imsave("Test/test-0072_S_AS_GW.png", c_weng_test_image7)
imsave("Test/test-0072_S_CS_GW.png", c_weng_test_image8)
imsave("Test/test-0072_S_FF_GW.png", c_weng_test_image9)
imsave("Test/test-0072_S_L_GW.png", c_weng_test_image10)
imsave("Test/test-0072_S_N_GW.png", c_weng_test_image11)
imsave("Test/test-0072_S_P_GW.png", c_weng_test_image12)
imsave("Truth/true-0097_GW.png", d_weng_reference_image)
imsave("Test/test-0097_F_AS_GW.png", d_weng_test_image1)
imsave("Test/test-0097_F_CS_GW.png", d_weng_test_image2)
imsave("Test/test-0097_F_FF_GW.png", d_weng_test_image3)
imsave("Test/test-0097_F_L_GW.png", d_weng_test_image4)
imsave("Test/test-0097_F_N_GW.png", d_weng_test_image5)
imsave("Test/test-0097_F_P_GW.png", d_weng_test_image6)
imsave("Test/test-0097_S_AS_GW.png", d_weng_test_image7)
imsave("Test/test-0097_S_CS_GW.png", d_weng_test_image8)
imsave("Test/test-0097_S_FF_GW.png", d_weng_test_image9)
imsave("Test/test-0097_S_L_GW.png", d_weng_test_image10)
imsave("Test/test-0097_S_N_GW.png", d_weng_test_image11)
imsave("Test/test-0097_S_P_GW.png", d_weng_test_image12)
imsave("Truth/true-0104_GW.png", e_weng_reference_image)
imsave("Test/test-0104_F_AS_GW.png", e_weng_test_image1)
imsave("Test/test-0104_F_CS_GW.png", e_weng_test_image2)
imsave("Test/test-0104_F_FF_GW.png", e_weng_test_image3)
imsave("Test/test-0104_F_L_GW.png", e_weng_test_image4)
imsave("Test/test-0104_F_N_GW.png", e_weng_test_image5)
imsave("Test/test-0104_F_P_GW.png", e_weng_test_image6)
imsave("Test/test-0104_S_AS_GW.png", e_weng_test_image7)
imsave("Test/test-0104_S_CS_GW.png", e_weng_test_image8)
imsave("Test/test-0104_S_FF_GW.png", e_weng_test_image9)
imsave("Test/test-0104_S_L_GW.png", e_weng_test_image10)
imsave("Test/test-0104_S_N_GW.png", e_weng_test_image11)
imsave("Test/test-0104_S_P_GW.png", e_weng_test_image12)
